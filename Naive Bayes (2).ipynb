# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
from sklearn.naive_bayes import BernoulliNB
naive=BernoulliNB()
from sklearn.naive_bayes import GaussianNB
gauss=GaussianNB()
from sklearn.naive_bayes import MultinomialNB
multi=MultinomialNB()
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
a=pd.read_csv(r'C:\Users\aksha\Downloads\SalaryData_Train.csv')

# %%
b=pd.read_csv(r'C:\Users\aksha\Downloads\SalaryData_Test.csv')

# %%
a
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
print(a.info())
print(b.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# ...

# %%
a.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
a[['workclass','education','maritalstatus','occupation','relationship','race','sex','native']]=a[['workclass','education','maritalstatus','occupation','relationship','race','sex','native']].astype('category')

# %%
a
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
a['Salary']=label.fit_transform(a['Salary'])

# %%
a
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
a['workclass']=a['workclass'].cat.codes

# %%
a['education']=a['education'].cat.codes

# %%
a['maritalstatus']=a['maritalstatus'].cat.codes
a['occupation']=a['occupation'].cat.codes
a['relationship']=a['relationship'].cat.codes
a['race']=a['race'].cat.codes
a['sex']=a['sex'].cat.codes

a['native']=a['native'].cat.codes

# %%
a
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  int8
#  2   education      30161 non-null  int8
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  int8
#  5   occupation     30161 non-null  int8
#  6   relationship   30161 non-null  int8
#  7   race           30161 non-null  int8
#  8   sex            30161 non-null  int8
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  int8
#  13  Salary         30161 non-null  int32
# dtypes: int32(1), int64(5), int8(8)
# memory usage: 1.5 MB

# %%
a.describe()
# Out:
#                 age    workclass    education   educationno  maritalstatus  \
# count  30161.000000  30161.00000  30161.00000  30161.000000   30161.000000
# mean      38.438115      2.19933     10.33361     10.121316       2.580087
# std       13.134830      0.95394      3.81226      2.550037       1.498018
# min       17.000000      0.00000      0.00000      1.000000       0.000000
# 25%       28.000000      2.00000      9.00000      9.000000       2.000000
# 50%       37.000000      2.00000     11.00000     10.000000       2.000000
# 75%       47.000000      2.00000     12.00000     13.000000       4.000000
# max       90.000000      6.00000     15.00000     16.000000       6.000000
#
#          occupation  relationship          race           sex   capitalgain  \
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean       5.959849      1.418322      3.678592      0.675707   1092.044064
# ...

# %%
x_train=a.drop('Salary',axis=1)
y_train=a[['Salary']]

# %%
print(x_train,y_train)
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
b
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
b[['workclass','education','maritalstatus','occupation','relationship','race','sex','native']]=b[['workclass','education','maritalstatus','occupation','relationship','race','sex','native']].astype('category')

# %%
b['Salary']=label.fit_transform(b['Salary'])
b
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
b['workclass']=b['workclass'].cat.codes
b['education']=b['education'].cat.codes
b['maritalstatus']=b['maritalstatus'].cat.codes
b['occupation']=b['occupation'].cat.codes
b['relationship']=b['relationship'].cat.codes
b['race']=b['race'].cat.codes
b['sex']=b['sex'].cat.codes
b['native']=b['native'].cat.codes

# %%
b
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
x_test=b.drop('Salary',axis=1)

# %%
y_test=b[['Salary']]

# %%
naive.fit(x_train,y_train)
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB()

# %%
y_predt=naive.predict(x_test)

# %%
accuracy_score(y_test,y_predt)
# Out:
# 0.7284196547144755

# %%
gauss.fit(x_train,y_train)
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_predt1=gauss.predict(x_test)

# %%
print(accuracy_score(y_test,y_predt1))
# Out:
# [0 1 1 ... 1 0 1]
# 0.7946879150066402

# %%
multi.fit(x_train,y_train)
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
y_predt2=multi.predict(x_test)

# %%
print(accuracy_score(y_test,y_predt2))
# Out:
# 0.7749667994687915
